# %%
# Installation automatique des dépendances requises dans le noyau Jupyter actuel
# %pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pandas>=2.0.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: numpy>=1.24.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 3)) (1.26.4)
# Requirement already satisfied: scikit-learn>=1.2.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 6)) (1.8.0)
# Requirement already satisfied: tensorflow>=2.12.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 7)) (2.16.2)
# Requirement already satisfied: matplotlib>=3.7.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 10)) (3.10.9)
# Requirement already satisfied: seaborn>=0.12.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 11)) (0.13.2)
# Requirement already satisfied: plotnine>=0.12.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 12)) (0.15.4)
# Requirement already satisfied: ipykernel in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 15)) (7.2.0)
# Requirement already satisfied: jupyter in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 16)) (1.1.1)
# Requirement already satisfied: quarto in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from -r ../requirements.txt (line 17)) (0.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from pandas>=2.0.0->-r ../requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.10.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 6)) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 6)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from scikit-learn>=1.2.0->-r ../requirements.txt (line 6)) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.16.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.4.0)
# Requirement already satisfied: packaging in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (26.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (4.25.9)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2.34.2)
# Requirement already satisfied: setuptools in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (82.0.1)
# Requirement already satisfied: six>=1.12.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (1.80.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.37.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.15)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (2026.4.22)
# Requirement already satisfied: markdown>=2.6.8 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.1.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (1.5.0)
# Requirement already satisfied: pillow>=8 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r ../requirements.txt (line 10)) (3.3.2)
# Requirement already satisfied: mizani~=0.14.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from plotnine>=0.12.0->-r ../requirements.txt (line 12)) (0.14.4)
# Requirement already satisfied: statsmodels>=0.14.6 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from plotnine>=0.12.0->-r ../requirements.txt (line 12)) (0.14.6)
# Requirement already satisfied: appnope>=0.1.2 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (9.13.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (0.2.2)
# Requirement already satisfied: nest-asyncio>=1.4 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (6.5.5)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipykernel->-r ../requirements.txt (line 15)) (5.15.0)
# Requirement already satisfied: notebook in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyter->-r ../requirements.txt (line 16)) (7.5.6)
# Requirement already satisfied: jupyter-console in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyter->-r ../requirements.txt (line 16)) (6.6.3)
# Requirement already satisfied: nbconvert in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyter->-r ../requirements.txt (line 16)) (7.17.1)
# Requirement already satisfied: ipywidgets in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyter->-r ../requirements.txt (line 16)) (8.1.8)
# Requirement already satisfied: jupyterlab in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyter->-r ../requirements.txt (line 16)) (4.5.7)
# Requirement already satisfied: nbformat in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from quarto->-r ../requirements.txt (line 17)) (5.10.4)
# Requirement already satisfied: nbclient in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from quarto->-r ../requirements.txt (line 17)) (0.10.4)
# Requirement already satisfied: pyyaml in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from quarto->-r ../requirements.txt (line 17)) (6.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.47.0)
# Requirement already satisfied: decorator>=5.1.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.20.0)
# Requirement already satisfied: pexpect>4.6 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.6.3)
# Requirement already satisfied: wcwidth in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.8.7)
# Requirement already satisfied: platformdirs>=2.5 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->-r ../requirements.txt (line 15)) (4.9.6)
# Requirement already satisfied: rich in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (15.0.0)
# Requirement already satisfied: namex in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.1.0)
# Requirement already satisfied: optree in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from keras>=3.0.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.19.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from pexpect>4.6->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r ../requirements.txt (line 15)) (0.2.3)
# Requirement already satisfied: patsy>=0.5.6 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from statsmodels>=0.14.6->plotnine>=0.12.0->-r ../requirements.txt (line 12)) (1.0.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (3.0.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 16)) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from ipywidgets->jupyter->-r ../requirements.txt (line 16)) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.18.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.2.4)
# Requirement already satisfied: anyio in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.14.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (25.1.0)
# Requirement already satisfied: attrs>=22.2.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (0.1.1)
# Requirement already satisfied: fqdn in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.1.0)
# Requirement already satisfied: uri-template in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 16)) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 16)) (6.3.0)
# Requirement already satisfied: defusedxml in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 16)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 16)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 16)) (3.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from nbconvert->jupyter->-r ../requirements.txt (line 16)) (1.5.1)
# Requirement already satisfied: webencodings in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 16)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->-r ../requirements.txt (line 16)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from nbformat->quarto->-r ../requirements.txt (line 17)) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2.0.0)
# Requirement already satisfied: pycparser in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from beautifulsoup4->nbconvert->jupyter->-r ../requirements.txt (line 16)) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (1.4.0)
# Requirement already satisfied: tzdata in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r ../requirements.txt (line 16)) (2026.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from rich->keras>=3.0.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (4.2.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/hobb/Documents/GitHub/aptispace-datascience-projet/venv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow>=2.12.0->-r ../requirements.txt (line 7)) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 🧹 Étape 2 : Préparation & Nettoyage de Données (Data Wrangling) (Squelette Étudiant)
#
# Cette étape correspond au deuxième chapitre du projet. L'objectif est d'effectuer un audit de qualité de vos données brutes, puis de mettre en œuvre un nettoyage rigoureux à l'aide de votre package personnalisé `src.data_clean`.

# %% [markdown]
# ### 1. Initialisation et imports

# %%
import os
import sys
import pandas as pd
import numpy as np

# Ajout du dossier parent pour importer 'src'
sys.path.append(os.path.abspath('..'))
from src import data_clean as dc

print("Librairies prêtes pour le Wrangling !")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 8
#       4 import numpy as np
#       5
#       6 # Ajout du dossier parent pour importer 'src'
#       7 sys.path.append(os.path.abspath('..'))
# ----> 8 from src import data_clean as dc
#       9
#      10 print("Librairies prêtes pour le Wrangling !")
#
# ImportError: cannot import name 'data_clean' from 'src' (/Users/hobb/Documents/GitHub/aptispace-datascience-projet/src/__init__.py)

# %% [markdown]
# ### 2. Chargement du dataset brut et Audit Initial
#
# **À COMPLÉTER PAR L'ÉTUDIANT :**
# Chargez les données brutes et inspectez la qualité du dataset (taux de valeurs manquantes, présence de doublons, types erronés).

# %%
raw_data_path = '../data/raw/train.csv'

df_raw = dc.load_raw_data(raw_data_path)

# Audit rapide
print("✔ INFO DATASET")
df_raw.info()

print("✔ VALEURS MANQUANTES")
print(df_raw.isnull().sum().sort_values(ascending=False).head(20))

print("✔ DOUBLONS :", df_raw.duplicated().sum())

# %% [markdown]
# ### 3. Uniformisation des Formats de Dates
#
# **À COMPLÉTER PAR L'ÉTUDIANT :**
# Uniformisez la colonne temporelle pour la convertir dans un type datetime standardisé via votre module `src.data_clean`.

# %%
# House Prices contient "YearBuilt" et "YrSold"
df_clean = df_raw.copy()

df_clean['YearBuilt'] = pd.to_datetime(df_clean['YearBuilt'], format='%Y', errors='coerce')
df_clean['YrSold'] = pd.to_datetime(df_clean['YrSold'], format='%Y', errors='coerce')

print("✔ Dates standardisées")
df_clean[['YearBuilt', 'YrSold']].head()

# %% [markdown]
# ### 4. Identification et Filtrage des Valeurs Aberrantes (Outliers)
#
# **À COMPLÉTER PAR L'ÉTUDIANT :**
# Identifiez les anomalies physiques et utilisez votre fonction `dc.handle_outliers` pour transformer ces valeurs aberrantes en NaNs.

# %%
# On cible les variables importantes
cols_outliers = ['GrLivArea', 'SalePrice']

df_no_outliers = dc.handle_outliers(
    df_clean,
    cols_outliers,
    lower_bound=0,
    upper_bound=500000  # seuil réaliste immobilier
)

df_no_outliers.describe()

# %% [markdown]
# ### 5. Imputation des valeurs manquantes
#
# **À COMPLÉTER PAR L'ÉTUDIANT :**
# Appliquez des stratégies d'imputation adaptées (interpolation temporelle, médiane, etc.) sur les valeurs manquantes générées ou initiales.

# %%
# Colonnes numériques principales
num_cols = df_no_outliers.select_dtypes(include="number").columns

df_final = dc.impute_missing_values(
    df_no_outliers,
    num_cols,
    method='median'
)

print("✔ Valeurs manquantes restantes :")
print(df_final.isnull().sum().sum())

# %% [markdown]
# ### 6. Sauvegarde des données propres
#
# Enregistrez vos données de base nettoyées dans le répertoire `data/processed/`.

# %%
processed_path = '../data/processed/cleaned_data_sample.csv'

df_final.to_csv(processed_path, index=False)

print(f"💾 Données propres sauvegardées dans : {processed_path}")
